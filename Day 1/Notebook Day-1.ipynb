# %%
# Load your data
df = spark.read.format("csv").option("header", "true").option("inferSchema", "true") \
            .load("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

# Verify it's working
print(f"✅ Ready to go! Loaded {df.count():,} events")
display(df.limit(5))
# Out:
# ✅ Ready to go! Loaded 42,448,764 events
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create simple DataFrame
data = [("Mak", 20,50000), ("Sam", 21,60000), ("James", 22,70000), ("John", 23,80000)]
df = spark.createDataFrame(data, ["name", "age", "salary"])
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>salary</th></tr></thead><tbody><tr><td>Mak</td><td>20</td><td>50000</td></tr><tr><td>Sam</td><td>21</td><td>60000</td></tr><tr><td>James</td><td>22</td><td>70000</td></tr><tr><td>John</td><td>23</td><td>80000</td></tr></tbody></table></div>

# %%
# Create simple DataFrame
data = [("Mak", 20,50000), ("Sam", 21,60000), ("James", 22,70000), ("John", 23,80000)]
df = spark.createDataFrame(data, ["name", "age", "salary"])

# filter salary > 60000
df_filter = df.filter(df.salary>60000)
display(df_filter)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>age</th><th>salary</th></tr></thead><tbody><tr><td>James</td><td>22</td><td>70000</td></tr><tr><td>John</td><td>23</td><td>80000</td></tr></tbody></table></div>
